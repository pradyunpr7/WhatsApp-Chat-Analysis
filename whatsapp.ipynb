# %%
import re
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# !pip install urlextract
import urlextract
# !pip install wordcloud
from wordcloud import WordCloud
# !pip install emoji
import emoji
# Out:
# Requirement already satisfied: urlextract in /Users/pradyunreddy/anaconda3/lib/python3.11/site-packages (1.8.0)
# Requirement already satisfied: idna in /Users/pradyunreddy/anaconda3/lib/python3.11/site-packages (from urlextract) (3.4)
# Requirement already satisfied: uritools in /Users/pradyunreddy/anaconda3/lib/python3.11/site-packages (from urlextract) (4.0.2)
# Requirement already satisfied: platformdirs in /Users/pradyunreddy/anaconda3/lib/python3.11/site-packages (from urlextract) (2.5.2)
# Requirement already satisfied: filelock in /Users/pradyunreddy/anaconda3/lib/python3.11/site-packages (from urlextract) (3.9.0)
# Requirement already satisfied: wordcloud in /Users/pradyunreddy/anaconda3/lib/python3.11/site-packages (1.9.2)
# Requirement already satisfied: numpy>=1.6.1 in /Users/pradyunreddy/anaconda3/lib/python3.11/site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in /Users/pradyunreddy/anaconda3/lib/python3.11/site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in /Users/pradyunreddy/anaconda3/lib/python3.11/site-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/pradyunreddy/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/pradyunreddy/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/pradyunreddy/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/pradyunreddy/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/pradyunreddy/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/pradyunreddy/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/pradyunreddy/anaconda3/lib/python3.11/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/pradyunreddy/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Requirement already satisfied: emoji in /Users/pradyunreddy/anaconda3/lib/python3.11/site-packages (2.8.0)

# %%
f=open('data/WhatsApp Chat with WAGDemoGroup.txt','r',encoding='utf-8')

# %%
data=f.read()

# %%
print(data)
# Out:
# 27/9/23, 19:11 - Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.
# 27/9/23, 19:11 - You created group "WAGDemoGroup"
# 27/9/23, 19:12 - Vedansh: Hey all
# 27/9/23, 19:12 - Vedansh: How are you all?
# 27/9/23, 19:14 - Vedansh: 😀😀
# 27/9/23, 19:15 - Naveen AU: Hloo
# 27/9/23, 19:15 - Vedansh: How are you Naveen?
# 27/9/23, 19:15 - Vedansh: All good?
# 27/9/23, 19:16 - Naveen AU: Yeah good man
# 27/9/23, 19:16 - Naveen AU: What about you
# 27/9/23, 19:16 - Vedansh: I'm fine 😊
# 27/9/23, 19:17 - Vedansh: Just a little stressed about college and exams 😔
# 27/9/23, 19:17 - Naveen AU: Say more
# 27/9/23, 19:17 - Naveen AU: Yes I Too!
# 27/9/23, 19:17 - Naveen AU: I'm tensed
# 27/9/23, 19:17 - Vedansh: It is really very consuming... getting really tired after college 😔
# 27/9/23, 19:18 - Naveen AU: Yes
# 27/9/23, 19:18 - Naveen AU: Where are our friends
# 27/9/23, 19:18 - Vedansh: Hey @919948603542
# 27/9/23, 19:18 - Vedansh: Hey @918522922311
# 27/9/23, 19:19 - Vedansh: You guys there?
# 27/9/23, 19:19 - Preethi AU: https://youtu.be/h3vZF9w2cVk?si=tvIRWnpirUx4_TVq
# 27/9/23, 19:19 - Vedansh: How are you guys preparing for the exam?
# 27/9/23, 19:20 - Vedansh: Woww... i really like her channel
# 27/9/23, 19:20 - Preethi AU: Watch out this to releif your stress😄
# 27/9/23, 19:20 - Vedansh: Her videos are really funny
# 27/9/23, 19:20 - Vedansh: Thanks Preethi 😁
# 27/9/23, 19:21 - Vedansh: Where is @919948603542 ?
# 27/9/23, 19:22 - Vedansh: I guess he is busy studying
# 27/9/23, 19:22 - Preethi AU: Mee too and I'm very much addicted to stress Busters
# 27/9/23, 19:23 - Preethi AU: Maybe🤷‍♀️
# 27/9/23, 19:23 - Vedansh: Fair enough 😂
# 27/9/23, 19:23 - Vedansh: We need her help to overcome our stress lol
# 27/9/23, 19:24 - Vedansh: https://youtu.be/E3D_s5f7fFc?si=eY8J8Sa9ggVWwOZ4
# 27/9/23, 19:25 - Vedansh: I'm really excited for this movie 😁
# 27/9/23, 19:25 - Vedansh: We all should plan for this movie after our exams
# 27/9/23, 19:26 - Preethi AU: Definitely 🙃
# 27/9/23, 19:27 - Vedansh: @916303685487 @919948603542 you guys in for the plan?
# 27/9/23, 19:27 - Naveen AU: Yes
# 27/9/23, 19:27 - Naveen AU: Definitely
# 27/9/23, 19:27 - Vedansh: You liked the glimpse?
# 27/9/23, 19:27 - Vedansh: Yayy! That's great 🥳
# 27/9/23, 19:28 - Naveen AU: 🤪🤪

# %%
pattern='\d{1,2}/\d{1,2}/\d{2,4},\s\d{1,2}:\d{2}\s-\s'

# %%
messages = re.split(pattern,data)[1:]
messages
# Out:
# ['Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.\n',
#  'You created group "WAGDemoGroup"\n',
#  'Vedansh: Hey all\n',
#  'Vedansh: How are you all?\n',
#  'Vedansh: 😀😀\n',
#  'Naveen AU: Hloo\n',
#  'Vedansh: How are you Naveen?\n',
#  'Vedansh: All good?\n',
#  'Naveen AU: Yeah good man\n',
#  'Naveen AU: What about you\n',
#  "Vedansh: I'm fine 😊\n",
#  'Vedansh: Just a little stressed about college and exams 😔\n',
#  'Naveen AU: Say more\n',
#  'Naveen AU: Yes I Too!\n',
#  "Naveen AU: I'm tensed\n",
#  'Vedansh: It is really very consuming... getting really tired after college 😔\n',
#  'Naveen AU: Yes\n',
#  'Naveen AU: Where are our friends\n',
#  'Vedansh: Hey @919948603542\n',
#  'Vedansh: Hey @918522922311\n',
#  'Vedansh: You guys there?\n',
#  'Preethi AU: https://youtu.be/h3vZF9w2cVk?si=tvIRWnpirUx4_TVq\n',
#  'Vedansh: How are you guys preparing for the exam?\n',
#  'Vedansh: Woww... i really like her channel\n',
#  'Preethi AU: Watch out this to releif your stress😄\n',
#  'Vedansh: Her videos are really funny\n',
#  'Vedansh: Thanks Preethi 😁\n',
#  'Vedansh: Where is @919948603542 ?\n',
#  'Vedansh: I guess he is busy studying\n',
#  "Preethi AU: Mee too and I'm very much addicted to stress Busters\n",
#  'Preethi AU: Maybe🤷\u200d♀️\n',
#  'Vedansh: Fair enough 😂\n',
#  'Vedansh: We need her help to overcome our stress lol\n',
#  'Vedansh: https://youtu.be/E3D_s5f7fFc?si=eY8J8Sa9ggVWwOZ4\n',
#  "Vedansh: I'm really excited for this movie 😁\n",
#  'Vedansh: We all should plan for this movie after our exams\n',
#  'Preethi AU: Definitely 🙃\n',
#  'Vedansh: @916303685487 @919948603542 you guys in for the plan?\n',
#  'Naveen AU: Yes\n',
#  'Naveen AU: Definitely\n',
#  'Vedansh: You liked the glimpse?\n',
#  "Vedansh: Yayy! That's great 🥳\n",
#  'Naveen AU: 🤪🤪\n']

# %%
dates=re.findall(pattern,data)
dates
# Out:
# ['27/9/23, 19:11 - ',
#  '27/9/23, 19:11 - ',
#  '27/9/23, 19:12 - ',
#  '27/9/23, 19:12 - ',
#  '27/9/23, 19:14 - ',
#  '27/9/23, 19:15 - ',
#  '27/9/23, 19:15 - ',
#  '27/9/23, 19:15 - ',
#  '27/9/23, 19:16 - ',
#  '27/9/23, 19:16 - ',
#  '27/9/23, 19:16 - ',
#  '27/9/23, 19:17 - ',
#  '27/9/23, 19:17 - ',
#  '27/9/23, 19:17 - ',
#  '27/9/23, 19:17 - ',
#  '27/9/23, 19:17 - ',
#  '27/9/23, 19:18 - ',
#  '27/9/23, 19:18 - ',
#  '27/9/23, 19:18 - ',
#  '27/9/23, 19:18 - ',
#  '27/9/23, 19:19 - ',
#  '27/9/23, 19:19 - ',
#  '27/9/23, 19:19 - ',
#  '27/9/23, 19:20 - ',
#  '27/9/23, 19:20 - ',
#  '27/9/23, 19:20 - ',
#  '27/9/23, 19:20 - ',
#  '27/9/23, 19:21 - ',
#  '27/9/23, 19:22 - ',
#  '27/9/23, 19:22 - ',
#  '27/9/23, 19:23 - ',
#  '27/9/23, 19:23 - ',
#  '27/9/23, 19:23 - ',
#  '27/9/23, 19:24 - ',
#  '27/9/23, 19:25 - ',
#  '27/9/23, 19:25 - ',
#  '27/9/23, 19:26 - ',
#  '27/9/23, 19:27 - ',
#  '27/9/23, 19:27 - ',
#  '27/9/23, 19:27 - ',
#  '27/9/23, 19:27 - ',
#  '27/9/23, 19:27 - ',
#  '27/9/23, 19:28 - ']

# %%
df = pd.DataFrame({'user_message': messages, 'message_date': dates})
df['message_date'] = pd.to_datetime(df['message_date'], format='%d/%m/%y, %H:%M - ')

df.rename(columns={'message_date':'date'} , inplace=True)
df.head()
# Out:
#                                         user_message                date
# 0  Messages and calls are end-to-end encrypted. N... 2023-09-27 19:11:00
# 1                 You created group "WAGDemoGroup"\n 2023-09-27 19:11:00
# 2                                 Vedansh: Hey all\n 2023-09-27 19:12:00
# 3                        Vedansh: How are you all?\n 2023-09-27 19:12:00
# 4                                      Vedansh: 😀😀\n 2023-09-27 19:14:00

# %%
df.shape
# Out:
# (43, 2)

# %%
users = []
messages = []
for message in df['user_message']:
    entry = re.split('([\w\W]+?):\s', message)
    if entry[1:]:  # user name
        users.append(entry[1])
        messages.append(" ".join(entry[2:]))
    else:
        users.append('group_notification')
        messages.append(entry[0])

df['user'] = users
df['message'] = messages
df.drop(columns=['user_message'], inplace=True)

df.head()
# Out:
#                  date                user  \
# 0 2023-09-27 19:11:00  group_notification
# 1 2023-09-27 19:11:00  group_notification
# 2 2023-09-27 19:12:00             Vedansh
# 3 2023-09-27 19:12:00             Vedansh
# 4 2023-09-27 19:14:00             Vedansh
#
#                                              message
# 0  Messages and calls are end-to-end encrypted. N...
# 1                 You created group "WAGDemoGroup"\n
# 2                                          Hey all\n
# 3                                 How are you all?\n
# 4                                               😀😀\n

# %%
df['only_date'] = df['date'].dt.date
df['year'] = df['date'].dt.year
df['month_num'] = df['date'].dt.month
df['month'] = df['date'].dt.month_name()
df['day'] = df['date'].dt.day
df['day_name'] = df['date'].dt.day_name()
df['hour'] = df['date'].dt.hour
df['minute'] = df['date'].dt.minute

# %%
df.head()
# Out:
#                  date                user  \
# 0 2023-09-27 19:11:00  group_notification
# 1 2023-09-27 19:11:00  group_notification
# 2 2023-09-27 19:12:00             Vedansh
# 3 2023-09-27 19:12:00             Vedansh
# 4 2023-09-27 19:14:00             Vedansh
#
#                                              message   only_date  year  \
# 0  Messages and calls are end-to-end encrypted. N...  2023-09-27  2023
# 1                 You created group "WAGDemoGroup"\n  2023-09-27  2023
# 2                                          Hey all\n  2023-09-27  2023
# 3                                 How are you all?\n  2023-09-27  2023
# 4                                               😀😀\n  2023-09-27  2023
#
#    month_num      month  day   day_name  hour  minute
# 0          9  September   27  Wednesday    19      11
# 1          9  September   27  Wednesday    19      11
# 2          9  September   27  Wednesday    19      12
# 3          9  September   27  Wednesday    19      12
# 4          9  September   27  Wednesday    19      14

# %%
user_list=df['user'].unique().tolist()
if 'group_notification' in user_list:
    user_list.remove('group_notification')
user_list.sort()
users = pd.DataFrame(user_list,columns=['Users'])
users = users.rename(index = lambda x: x + 1)

# %%
msgs=df['user'].tolist()
nom=[]
for i in user_list:
    nom.append(msgs.count(i))
users['Total Number of Messages']=nom
users.head()
# Out:
#         Users  Total Number of Messages
# 1   Naveen AU                        11
# 2  Preethi AU                         5
# 3     Vedansh                        25

# %%
y=np.array(nom)
plt.pie(y,labels=user_list,autopct='%1.0f%%')
plt.show()

# %%
mostdays=df['day_name'].tolist()
days=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']
md=df['day_name'].unique().tolist()
y=[]
for i in days:
    if i in md:
        y.append(mostdays.count(i))
    else:
        y.append(0)
xy=np.array(y)
plt.pie(xy,labels=days,autopct='%1.0f%%')
plt.legend(bbox_to_anchor=(0.7, 1.15))
plt.show()

# %%
from urlextract import URLExtract

extractor = URLExtract()
links = []
for message in df['message']:
    links.extend(extractor.find_urls(message))

# %%
li=[]
med=[]
use=[]
for i in user_list:
    use=[]
    d=0
    nf=df[df['user']==i]
    for message in nf['message']:
        if message=='<Media omitted>\n':
            d+=1
        use.extend(extractor.find_urls(message))
    li.append(len(use))
    med.append(d)
users['Number of links shared']=li
users['Number of Media Shared']=med
users.head()
# Out:
#         Users  Total Number of Messages  Number of links shared  \
# 1   Naveen AU                        11                       0
# 2  Preethi AU                         5                       1
# 3     Vedansh                        25                       1
#
#    Number of Media Shared
# 1                       0
# 2                       0
# 3                       0

# %%
textm=[]
for i,j,k in zip(li,med,nom):
    x=k-i-j
    textm.append(x)

# %%
users['Number of Text Messages']=textm
users.head()
# Out:
#         Users  Total Number of Messages  Number of links shared  \
# 1   Naveen AU                        11                       0
# 2  Preethi AU                         5                       1
# 3     Vedansh                        25                       1
#
#    Number of Media Shared  Number of Text Messages
# 1                       0                       11
# 2                       0                        4
# 3                       0                       24

# %%
wc=WordCloud(width=500,height=500,min_font_size=10,background_color='white')
wcount=wc.generate(df['message'].str.cat(sep=' '))
plt.imshow(wcount)

# %%
words=[]
for message in df['message']:
    words.extend(message.split())

# %%
f=open('data/stop words.txt','r')
stop=f.read()
s=stop.split('\n')

# %%
words=[]
temp=df[df['user']!='group_notification']
temp=temp[temp['message']!='<Media omitted>\n']
fp=temp
for message in temp['message']:
    k=[]
    for word in message.lower().split():
        if word not in s:
            if word not in links:
                k.append(word)
    words.append(' '.join(k))

# %%
x=[]
for i in words:
    s=i.strip(' ')
    s=s.strip('.')
    s=s.strip(',')
    s=s.strip('$')
    s=s.strip('?')
    s=s.strip('%')
    if s.isalpha()==True:
        x.append(s)
words=x
words


from collections import Counter
top_words=pd.DataFrame(Counter(words).most_common(10),columns=['Message Word','Frequency'])
top_words = top_words.rename(index = lambda x: x + 1)
top_words
# Out:
#   Message Word  Frequency
# 1          all          2
# 2         hloo          1
# 3       naveen          1
# 4   definitely          1

# %%
st='\n'.join(words)
file=open('data/Words.txt','w')
file.write(st)
file.close()

# %%
emojis=[]
for message in df['message']:
    emojis.extend([c for c in message if emoji.is_emoji('c')])

# %%
pd.DataFrame(Counter(emojis).most_common(len(Counter(emojis))))
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df['month_num']=df['date'].dt.month

# %%
timeline=df.groupby(['year','month_num','month']).count()['message'].reset_index()

# %%
timeline
# Out:
#    year  month_num      month  message
# 0  2023          9  September       43

# %%
time=[]
for i in range(timeline.shape[0]):
    time.append(timeline['month'][i] + ' - '+str(timeline['year'][i]))

# %%
timeline['time']=time
timeline
# Out:
#    year  month_num      month  message              time
# 0  2023          9  September       43  September - 2023

# %%
plt.plot(timeline['time'],timeline['message'])
plt.xticks(rotation='vertical')
plt.show()

# %%
period=[]
for hour in df[['day_name','hour']]['hour']:
    if hour==23:
        period.append(str(hour)+"-"+str('00'))
    elif hour==0:
        period.append(str('00')+'-'+str(hour+1))
    else:
        period.append(str(hour)+'-'+str(hour+1))

# %%
df['period']=period

# %%
import seaborn as sns
plt.figure(figsize=(20,6))
sns.heatmap(df.pivot_table(index='day_name',columns='period',values='message',aggfunc='count').fillna(0))
plt.yticks(rotation='horizontal')
plt.show()

# %%
from sklearn.feature_extraction.text import CountVectorizer
def predict_emotion(cv,sample_text,model):
    myvect = cv.transform(sample_text).toarray()
    prediction = model.predict(myvect)
    pred_proba = model.predict_proba(myvect)
    pred_percentage_for_all = dict(zip(model.classes_,pred_proba[0]))
    return (prediction[0])
    #pred_percentage_for_all

# %%
import joblib
cv=joblib.load('data/vector.pkl')
model=joblib.load('data/emotion_classifier.pkl')
# Out:
# /Users/pradyunreddy/anaconda3/lib/python3.11/site-packages/sklearn/base.py:347: InconsistentVersionWarning: Trying to unpickle estimator CountVectorizer from version 1.2.1 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/pradyunreddy/anaconda3/lib/python3.11/site-packages/sklearn/base.py:347: InconsistentVersionWarning: Trying to unpickle estimator MultinomialNB from version 1.2.1 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
predict_emotion(cv,["I am so scared"],model)
# Out:
# 'fear'

# %%
k=fp["message"]
res=[]
for i in k:
        s=i.strip("\n")
        if s not in links:
            res.append(s)
res
# Out:
# ['Hey all',
#  'How are you all?',
#  '😀😀',
#  'Hloo',
#  'How are you Naveen?',
#  'All good?',
#  'Yeah good man',
#  'What about you',
#  "I'm fine 😊",
#  'Just a little stressed about college and exams 😔',
#  'Say more',
#  'Yes I Too!',
#  "I'm tensed",
#  'It is really very consuming... getting really tired after college 😔',
#  'Yes',
#  'Where are our friends',
#  'Hey @919948603542',
#  'Hey @918522922311',
#  'You guys there?',
#  'How are you guys preparing for the exam?',
#  'Woww... i really like her channel',
#  'Watch out this to releif your stress😄',
#  'Her videos are really funny',
#  'Thanks Preethi 😁',
#  'Where is @919948603542 ?',
#  'I guess he is busy studying',
#  "Mee too and I'm very much addicted to stress Busters",
#  'Maybe🤷\u200d♀️',
#  'Fair enough 😂',
#  'We need her help to overcome our stress lol',
#  "I'm really excited for this movie 😁",
#  'We all should plan for this movie after our exams',
#  'Definitely 🙃',
#  '@916303685487 @919948603542 you guys in for the plan?',
#  'Yes',
#  'Definitely',
#  'You liked the glimpse?',
#  "Yayy! That's great 🥳",
#  '🤪🤪']

# %%
dic={"sadness":0,"anger":0,"disgust":0,"fear":0,"joy":0,"neutral":0,"shame":0,"surprise":0}
for i in res:
    d=[i]
    a=predict_emotion(cv,d,model)
    dic[a]+=1
print(dic)
# Out:
# {'sadness': 4, 'anger': 0, 'disgust': 0, 'fear': 0, 'joy': 33, 'neutral': 2, 'shame': 0, 'surprise': 0}

# %%
em=[]
val=[]
for i in dic:
    em.append(i)
    val.append(dic[i])

ab=np.array(val)
plt.pie(ab,labels=em,autopct='%1.0f%%')
plt.legend(bbox_to_anchor=(0.7, 1.15))
plt.show()
